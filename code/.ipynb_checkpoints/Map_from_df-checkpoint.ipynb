# %%
# !pip install ExifRead

# %%
import exifread

# %%
import requests
import re

# %%
from IPython.display import Image

# %%
#could rotate street view image auotmatically until it has highest correlation

# %%
f = open('../../IMG_4105S.JPG')

# Return Exif tags
tags = exifread.process_file(f)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-286-69c176983698> in <module>()
#       2
#       3 # Return Exif tags
# ----> 4 tags = exifread.process_file(f)
#
# /anaconda3/envs/dsi/lib/python3.6/site-packages/exifread/__init__.py in process_file(f, stop_tag, details, strict, debug)
#      29
#      30     # determine whether it's a JPEG or TIFF
# ---> 31     data = f.read(12)
#      32     if data[0:4] in [b'II*\x00', b'MM\x00*']:
#      33         # it's a TIFF file
#
# /anaconda3/envs/dsi/lib/python3.6/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte

# %%
t = open('../../IMG_4106N.JPG')

# %%
f = open('../../IMG_4114.JPG', 'rb')
tags = exifread.process_file(f)

# %%
type(tags['Image Orientation'])
# Out:
# exifread.classes.IfdTag

# %%
tags
# Out:
# {'Image Make': (0x010F) ASCII=Apple @ 146,
#  'Image Model': (0x0110) ASCII=iPhone 6 @ 152,
#  'Image Orientation': (0x0112) Short=Rotated 90 CW @ 42,
#  'Image XResolution': (0x011A) Ratio=72 @ 162,
#  'Image YResolution': (0x011B) Ratio=72 @ 170,
#  'Image ResolutionUnit': (0x0128) Short=Pixels/Inch @ 78,
#  'Image Software': (0x0131) ASCII=12.0.1 @ 178,
#  'Image DateTime': (0x0132) ASCII=2019:01:08 14:13:44 @ 186,
#  'Image YCbCrPositioning': (0x0213) Short=Centered @ 114,
#  'Image ExifOffset': (0x8769) Long=206 @ 126,
#  'GPS GPSLatitudeRef': (0x0001) ASCII=N @ 1700,
#  'GPS GPSLatitude': (0x0002) Ratio=[38, 54, 169/10] @ 1876,
#  'GPS GPSLongitudeRef': (0x0003) ASCII=W @ 1724,
#  'GPS GPSLongitude': (0x0004) Ratio=[77, 2, 469/100] @ 1900,
#  'GPS GPSAltitudeRef': (0x0005) Byte=0 @ 1748,
#  'GPS GPSAltitude': (0x0006) Ratio=135885/4769 @ 1924,
#  'GPS GPSTimeStamp': (0x0007) Ratio=[19, 13, 4333/100] @ 1932,
#  'GPS GPSSpeedRef': (0x000C) ASCII=K @ 1784,
#  'GPS GPSSpeed': (0x000D) Ratio=0 @ 1956,
#  'GPS GPSImgDirectionRef': (0x0010) ASCII=T @ 1808,
#  'GPS GPSImgDirection': (0x0011) Ratio=161762/837 @ 1964,
#  'GPS GPSDestBearingRef': (0x0017) ASCII=T @ 1832,
#  'GPS GPSDestBearing': (0x0018) Ratio=161762/837 @ 1972,
#  'GPS GPSDate': (0x001D) ASCII=2019:01:08 @ 1980,
#  'GPS Tag 0x001F': (0x001F) Ratio=65 @ 1992,
#  'Image GPSInfo': (0x8825) Long=1690 @ 138,
#  'Thumbnail Compression': (0x0103) Short=JPEG (old-style) @ 2010,
#  'Thumbnail XResolution': (0x011A) Ratio=72 @ 2078,
#  'Thumbnail YResolution': (0x011B) Ratio=72 @ 2086,
#  'Thumbnail ResolutionUnit': (0x0128) Short=Pixels/Inch @ 2046,
#  'Thumbnail JPEGInterchangeFormat': (0x0201) Long=2094 @ 2058,
#  'Thumbnail JPEGInterchangeFormatLength': (0x0202) Long=5060 @ 2070,
#  'EXIF ExposureTime': (0x829A) Ratio=1/30 @ 596,
#  'EXIF FNumber': (0x829D) Ratio=11/5 @ 604,
#  'EXIF ExposureProgram': (0x8822) Short=Program Normal @ 240,
#  'EXIF ISOSpeedRatings': (0x8827) Short=64 @ 252,
#  'EXIF ExifVersion': (0x9000) Undefined=0221 @ 264,
#  'EXIF DateTimeOriginal': (0x9003) ASCII=2019:01:08 14:13:44 @ 612,
#  'EXIF DateTimeDigitized': (0x9004) ASCII=2019:01:08 14:13:44 @ 632,
#  'EXIF ComponentsConfiguration': (0x9101) Undefined=YCbCr @ 300,
#  'EXIF ShutterSpeedValue': (0x9201) Signed Ratio=47079/9593 @ 652,
#  'EXIF ApertureValue': (0x9202) Ratio=193685/85136 @ 660,
#  'EXIF BrightnessValue': (0x9203) Signed Ratio=86831/33814 @ 668,
#  'EXIF ExposureBiasValue': (0x9204) Signed Ratio=0 @ 676,
#  'EXIF MeteringMode': (0x9207) Short=Pattern @ 360,
#  'EXIF Flash': (0x9209) Short=Flash did not fire, auto mode @ 372,
#  'EXIF FocalLength': (0x920A) Ratio=83/20 @ 684,
#  'EXIF SubjectArea': (0x9214) Short=[1631, 1223, 1795, 1077] @ 692,
#  'EXIF MakerNote': (0x927C) Undefined=[65, 112, 112, 108, 101, 32, 105, 79, 83, 0, 0, 1, 77, 77, 0, 17, 0, 1, 0, 9, ... ] @ 700,
#  'EXIF SubSecTimeOriginal': (0x9291) ASCII=799 @ 420,
#  'EXIF SubSecTimeDigitized': (0x9292) ASCII=799 @ 432,
#  'EXIF FlashPixVersion': (0xA000) Undefined=0100 @ 444,
#  'EXIF ColorSpace': (0xA001) Short=sRGB @ 456,
#  'EXIF ExifImageWidth': (0xA002) Long=3264 @ 468,
#  'EXIF ExifImageLength': (0xA003) Long=2448 @ 480,
#  'EXIF SensingMethod': (0xA217) Short=One-chip color area @ 492,
#  'EXIF SceneType': (0xA301) Undefined=Directly Photographed @ 504,
#  'EXIF ExposureMode': (0xA402) Short=Auto Exposure @ 516,
#  'EXIF WhiteBalance': (0xA403) Short=Auto @ 528,
#  'EXIF FocalLengthIn35mmFilm': (0xA405) Short=29 @ 540,
#  'EXIF SceneCaptureType': (0xA406) Short=Standard @ 552,
#  'EXIF LensSpecification': (0xA432) Ratio=[83/20, 83/20, 11/5, 11/5] @ 1618,
#  'EXIF LensMake': (0xA433) ASCII=Apple @ 1650,
#  'EXIF LensModel': (0xA434) ASCII=iPhone 6 back camera 4.15mm f/2.2 @ 1656,
#  'MakerNote Tag 0x0001': (0x0001) Signed Long=10 @ 10,
#  'MakerNote Tag 0x0002': (0x0002) Undefined=[212, 3, 7, 2, 43, 0, 81, 0, 76, 0, 73, 0, 71, 0, 61, 0, 79, 0, 99, 0, ... ] @ 224,
#  'MakerNote Tag 0x0003': (0x0003) Undefined=[6, 7, 8, 85, 102, 108, 97, 103, 115, 85, 118, 97, 108, 117, 101, 89, 116, 105, 109, 101, ... ] @ 782,
#  'MakerNote Tag 0x0004': (0x0004) Signed Long=1 @ 46,
#  'MakerNote Tag 0x0005': (0x0005) Signed Long=128 @ 58,
#  'MakerNote Tag 0x0006': (0x0006) Signed Long=124 @ 70,
#  'MakerNote Tag 0x0007': (0x0007) Signed Long=1 @ 82,
#  'MakerNote Tag 0x0008': (0x0008) Signed Ratio=[-2053308418/-186318847, -1899036672/0, 1/83] @ 886,
#  'MakerNote Tag 0x0009': (0x0009) Signed Long=275 @ 106,
#  'MakerNote Tag 0x000E': (0x000E) Signed Long=0 @ 118,
#  'MakerNote Tag 0x0014': (0x0014) Signed Long=4 @ 130,
#  'MakerNote Tag 0x0017': (0x0017) Signed Long=0 @ 142,
#  'MakerNote Tag 0x0019': (0x0019) Signed Long=0 @ 154,
#  'MakerNote Tag 0x001F': (0x001F) Signed Long=0 @ 166,
#  'MakerNote Tag 0x0025': (0x0025) Signed Long=0 @ 178,
#  'MakerNote Tag 0x0026': (0x0026) Signed Long=0 @ 190,
#  'MakerNote Tag 0x0027': (0x0027) Signed Ratio=20/83 @ 910,
#  'JPEGThumbnail': b'\xff\xd8\xff\xdb\x00\x84\x00\x01\x01\x01\x01\x01\x01\x02\x01\x01\x02\x03\x02\x02\x02\x03\x04\x03\x03\x03\x03\x04\x05\x04\x04\x04\x04\x04\x05\x06\x05\x05\x05\x05\x05\x05\x06\x06\x06\x06\x06\x06\x06\x06\x07\x07\x07\x07\x07\x07\x08\x08\x08\x08\x08\t\t\t\t\t\t\t\t\t\t\x01\x01\x01\x01\x02\x02\x02\x04\x02\x02\x04\t\x06\x05\x06\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\xff\xdd\x00\x04\x00\n\xff\xc0\x00\x11\x08\x00x\x00\xa0\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x01\xa2\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xfe\xfe+3Y\xdf\xfd\x95pc\x90\xc4B\x13\xbc\x1d\xa5q\xdf=\xabN\xb3\xb5t\x95\xf4\xd9R\x1cn#\x1f7Lg\x9f\xd2\xbb\xe9\xfcH\xea\x96\xc5\xa8\xb7\x08\x13q\xe4(\xc9>\xb8\xaf\xc8\x1f\xf8/\xf6\xa7\xfd\x93\xff\x00\x04m\xfd\xa0.s\x82\xfe\x19xG\xfd\xb6\xb8\x86?\xfd\x9a\xbf`T\xab\x0c\x8c\xe0ds_\x86\xdf\xf0rV\xab\xfd\x93\xff\x00\x04\\\xf8\xd8\xd9\xc7\xda,t\xfb\x7f\xfb\xfb\xa9Z\xad\x0fY\x19\xc4\xff\x00,_\x05\x84\x8f\xe1>\xaa\xfb\x0e\xe7{X\xcb\xe7\x8c\x19\t\x0b\x8e\xe7?\xa5}E\xf0\xc9\xed-\xbc"\x1a\xe62\xe5\xae\x18\x8eq\xc0\x00\x1a\xf8\x87H\xd5\xaf\xe1\xd1-\xf4H\xe4\xc5\xbc\xef\x13\xba\xe0r\xcax\xe7\xaf\x15\xf6\xff\x00\xc3\xe6\x99\xbc)mo\x1cj\xdb\xa5\x90\xee#$|\xdf\xfdj\xea\xc3\xc6\xd3\x91\xd3\x06\x8fI\x9a\xf6\xdd\xac\xc7\x93n\xa8w\x06\x0cI\'\xe5=9\xe3\x15\x8dm\x1d\x85\xfb\xcfy\xa9H\xd1\xe5\xc3\x0f.<\x82H9\xe3\x801Z7\xda\xb6\xafk\x04ih0\xcb\x18\x89H\x8c\x1c\x80Kzr}OZ\xcb\xd3u\xb6\xd4U\x07\x88dy-\xe2\x91\xb2\x14a\x80*3\x8cc\xbe+\xd9\xa8\xac\xacc\xcc\xaeU\xd4\x97A\xfb\x18M<\xcf+\xf9\xc8$\xf3\x02\xa8\xd8\x01?.\t\xe4\xe7\xbdQ\xf1%\xfe\x97u\xad\\^\xe8\x16\xbfc\xb5\x10\xba\xc7\x16s\x83\xb3\x1c\x9frsSiW\x1a*Cp\xda\x84sI\x99\xbeA\x1b( \x05\xe7$\xe7\xd4U\rOQ\xf0\xf8\xd2n\xa3\xb0\xb5\x969\x88P\xad$\x81\x80\x05\xd7#\x00\x0eH\xaf6\xac\xf4\x924\x8e\xb6f\x042\xb4P\x83\xfd\xd1\x9f\xca\xbe\xa4\xf0%\x8a\xc7{o\x1b\x0f\xf8\xf6\xd2mW\xf1\x95\x8b\x9f\xe5_*\xc6\xc6[\x17S\xd7i\x1f\xd2\xbe\xd2\xf0\x8d\xb2\xa6\xa9\xaa2\xf2"{{a\xf4\x86\x15\xfe\xack\xe5\xf3IYX\xf60\x8a\xe7b\xd0\x0e?J\xaea\xc1\xe4WE\xe4)\x1e\xb5BuD\x15\xf3r\x9fC\xd1\xe53\xbc\xbcs\x8ac(\x02\xac\x17\xf4\xaa\xd278\xac[)\xa2"\xaa(U\x03\xa5;<\x91GN\x95\x98\x9a\x05A\x9e*\xcep0*\x00\xf8\xe3\x1d)\xae\xfc\x1aL\xa8\xe8\x7f\xff\xd0\xfe\xfe*\x96\xa3\x8f\xb1\xb8##\x8c\x8c\xe3\xbf\xadY\xf3c\xf9y\x1f?\xdd\xf7\xaa\xf7\xe1Z\xd5\x91\xb0r@\xc1\xf5$b\xbb\xa1\xba:\xa7\xb3-\x8cv\xaf\xe7\x9f\xfe\x0e\x94\xd5\xbf\xb2\xbf\xe0\x8b\xff\x00\x12\x90\x1c}\xae\xf7C\xb7\xfa\xee\xd4\xe08\xff\x00\xc7k\xfa\x18\x15\xfc\xd0\xff\x00\xc1\xdaZ\x8f\xd8\x7f\xe0\x8e^"\xb7\xcf\xfc}\xf8\x9bA\x87\xeb\xfe\x92d\xff\x00\xd9(\x8a\xf7\x8eZn\xd1?\xcc\x17J9\x9e\xc6/t\xaf\xbf|\x10\x97\xb0\xf8R\xc5\xad\x9fhm\xe ...

# %%
tags['GPS GPSImgDirection'].values[0].num / tags['GPS GPSImgDirection'].values[0].den
# Out:
# 187.27166751140396

# %%
369487/1973
# Out:
# 187.27166751140396

# %%
tags_2['GPS GPSImgDirection'].values[0]
# Out:
# 334363/966

# %%
334363/966
# Out:
# 346.13146997929607

# %%
text_ = tags['Image Orientation'].printable
text_[1:]
# Out:
# 'otated 90 CW'

# %%
#taken from repo documentation:
def get_coordinates(filepath_str):
    f = open(filepath_str, 'rb')

    # Return Exif tags
    tags = exifread.process_file(f)
    
    lng_ref_tag_name = "GPS GPSLongitudeRef"
    lng_tag_name = "GPS GPSLongitude"
    lat_ref_tag_name = "GPS GPSLatitudeRef"
    lat_tag_name = "GPS GPSLatitude"

    # Check if these tags are present
    gps_tags = [lng_ref_tag_name,lng_tag_name,lat_tag_name,lat_tag_name]
    for tag in gps_tags:
        if not tag in tags.keys():
            print ("Skipping file. Tag {} not present.".format(tag))
            return None

    convert = lambda ratio: float(ratio.num)/float(ratio.den)

    lng_ref_val = tags[lng_ref_tag_name].values
    lng_coord_val = [convert(c) for c in tags[lng_tag_name].values]

    lat_ref_val = tags[lat_ref_tag_name].values
    lat_coord_val = [convert(c) for c in tags[lat_tag_name].values]

    lng_coord = sum([c/60**i for i,c in enumerate(lng_coord_val)])
    lng_coord *= (-1)**(lng_ref_val=="W")

    lat_coord = sum([c/60**i for i,c in enumerate(lat_coord_val)])
    lat_coord *= (-1)**(lat_ref_val=="S")

    heading = tags['GPS GPSImgDirection'].values[0].num / tags['GPS GPSImgDirection'].values[0].den
    return (lat_coord, lng_coord, heading)

# %%
def image_return(img_path_str, output_folder):
    coords = get_coordinates(img_path_str)
    address = f'+{coords[0]},{coords[1]}'
    heading = coords[2]
    url = f'https://maps.googleapis.com/maps/api/streetview?size=300x600&location={address}&heading={heading}&key=AIzaSyD3S31qCJdg6PtqLI4HxaKzO1CvSBk7ndc'
    img = requests.get(url)
    filelist = re.findall(r'\w+', address)
    filename = ''.join(filelist)
    final_path = f'{output_folder}/{filename}.jpg'
    open(final_path, 'wb').write(img.content)
    print(coords)
    print(heading)
    return Image(final_path)

# %%
image_return('../../IMG_4114.JPG','../images/')
# Out:
# (38.90368333333333, -77.00295277777778, 8.714528082864542)
# 8.714528082864542

# %%
Image('../../IMG_4114.JPG')

# %%
image_return('../../IMG_4106N.JPG','../images/')
# Out:
# 47.328010547905066

# %%
img_ = Image('../../IMG_4114.JPG',)

# %%
# Out:
# None

# %%
#file path widget

import os

import ipywidgets as widgets


class FileBrowser(object):
    def __init__(self):
        self.path = os.getcwd()
        self._update_files()
        
    def _update_files(self):
        self.files = list()
        self.dirs = list()
        if(os.path.isdir(self.path)):
            for f in os.listdir(self.path):
                ff = self.path + "/" + f
                if os.path.isdir(ff):
                    self.dirs.append(f)
                else:
                    self.files.append(f)
        
    def widget(self):
        box = widgets.VBox()
        self._update(box)
        return box
    
    def _update(self, box):
        
        def on_click(b):
            if b.description == '..':
                self.path = os.path.split(self.path)[0]
            else:
                self.path = self.path + "/" + b.description
            self._update_files()
            self._update(box)
        
        buttons = []
        if self.files:
            button = widgets.Button(description='..', background_color='#d0d0ff')
            button.on_click(on_click)
            buttons.append(button)
        for f in self.dirs:
            button = widgets.Button(description=f, background_color='#d0d0ff')
            button.on_click(on_click)
            buttons.append(button)
        for f in self.files:
            button = widgets.Button(description=f)
            button.on_click(on_click)
            buttons.append(button)
        box.children = tuple([widgets.HTML("<h2>%s</h2>" % (self.path,))] + buttons)

# %%
f = FileBrowser()
f.widget()
# Out:
# VBox(children=(HTML(value='<h2>/Users/zacharystern/Documents/GA/Project_4/project-4-team-street/code</h2>'), B…

# %%
up_image = f.path
up_image
# Out:
# '/Users/zacharystern/Documents/GA/Project_4/IMG_4105S.JPG'

# %%
image_return(up_image,'../images/')

# %%
#!pip install python-resize-image

# %%
import PIL as pl

from resizeimage import resizeimage

# %%
def photo_func(up_image):
    with open(up_image, 'r+b') as p:
        with pl.Image.open(p) as img:
            cover = resizeimage.resize_cover(img, [600, 300])
            cover.save('test-image-resize.jpeg')
    return Image('test-image-resize.jpeg')

# %%
photo_func(up_image)
